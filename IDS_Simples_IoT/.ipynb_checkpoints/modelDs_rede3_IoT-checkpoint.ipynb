# %%
#chamada 
#if __name__ == '__main__':
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix
import itertools    


from sklearn import model_selection
from keras.optimizers import SGD
from keras.optimizers import Adam
from collections import Counter
#vamos importar as classes para realizar o random RandomOverSampler e SMOTE
from imblearn.over_sampling import RandomOverSampler, SMOTE



from tqdm import tqdm
from keras import metrics
from keras.utils import np_utils
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
# Out:
# 2024-06-21 15:34:20.756424: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
checkpoint_callback = ModelCheckpoint(
    filepath='melhor__reduzido_2.h5', #caminho para salvar o arquivo do modelo
    monitor='val_loss', #métrica a ser monitorada
    save_best_only=True, #salvar apenas o melhor modelo
    save_weights_only=False, #salvar o nodelo completo incluindo a arquitetura
    mode='min', #salvar o modelo com a menor perda de validação
    verbose=1  # Modo de verbosidade (0 ou 1)
    
)
callback_stop_patience = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

#função de callbackt
class Mycallback(tf.keras.callbacks.Callback):
    def on_epochs_end(self, epoch, logs={}):
        if logs.get('accuracy') > 1.0:
            print('accuracy: 100%, vamos cancelar o treino! Essa condição já nos satisfaz!')
            self.model.stop_training = True

# %%
#vamos definir as métricas de avaliação
metricas = [
    metrics.FalseNegatives(name="fn"),
    metrics.FalsePositives(name="fp"),
    metrics.TrueNegatives(name="Tn"),
    metrics.TruePositives(name="Tp"),
    metrics.Precision(name="precision"),
    metrics.Recall(name="recall"),
    
]
# Out:
# 2024-06-21 15:34:48.262841: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
dict_7classes = {}
dict_7classes['DDoS-RSTFINFlood'] = 'DDoS'
dict_7classes['DDoS-PSHACK_Flood'] = 'DDoS'
dict_7classes['DDoS-SYN_Flood'] = 'DDoS'
dict_7classes['DDoS-UDP_Flood'] = 'DDoS'
dict_7classes['DDoS-TCP_Flood'] = 'DDoS'
dict_7classes['DDoS-ICMP_Flood'] = 'DDoS'
dict_7classes['DDoS-SynonymousIP_Flood'] = 'DDoS'
dict_7classes['DDoS-ACK_Fragmentation'] = 'DDoS'
dict_7classes['DDoS-UDP_Fragmentation'] = 'DDoS'
dict_7classes['DDoS-ICMP_Fragmentation'] = 'DDoS'
dict_7classes['DDoS-SlowLoris'] = 'DDoS'
dict_7classes['DDoS-HTTP_Flood'] = 'DDoS'

dict_7classes['DoS-UDP_Flood'] = 'DoS'
dict_7classes['DoS-SYN_Flood'] = 'DoS'
dict_7classes['DoS-TCP_Flood'] = 'DoS'
dict_7classes['DoS-HTTP_Flood'] = 'DoS'


dict_7classes['Mirai-greeth_flood'] = 'Mirai'
dict_7classes['Mirai-greip_flood'] = 'Mirai'
dict_7classes['Mirai-udpplain'] = 'Mirai'

dict_7classes['Recon-PingSweep'] = 'Recon'
dict_7classes['Recon-OSScan'] = 'Recon'
dict_7classes['Recon-PortScan'] = 'Recon'
dict_7classes['VulnerabilityScan'] = 'Recon'
dict_7classes['Recon-HostDiscovery'] = 'Recon'

dict_7classes['DNS_Spoofing'] = 'Spoofing'
dict_7classes['MITM-ArpSpoofing'] = 'Spoofing'

dict_7classes['BenignTraffic'] = 'Benign'

dict_7classes['BrowserHijacking'] = 'Web'
dict_7classes['Backdoor_Malware'] = 'Web'
dict_7classes['XSS'] = 'Web'
dict_7classes['Uploading_Attack'] = 'Web'
dict_7classes['SqlInjection'] = 'Web'
dict_7classes['CommandInjection'] = 'Web'


dict_7classes['DictionaryBruteForce'] = 'BruteForce'

# %%
def plotagem_dados(y):
    #contagem das classes
    data = Counter(y)
    #adicionando os valores de cada classe em uma lista
    counts = list(data.values())

    #nomes das categorias
    category_names = ['DDoS',
             'DoS',
             'Mirai',
             'Benign',
             'Spoofing',
             'Recon',
             'Web',
             'BruteForce'] 
    #craindo a figura
    plt.figure(figsize=(10,6))

    plt.bar(category_names, counts, color=['red','green','blue'])
    plt.xlabel('Categoria dos Ataques')
    plt.ylabel('Números de Ataques')
    plt.title('Ataques IoT')
    plt.show()

# %%
DATASET_DIRECTORY = 'CICIoT2023'
#dataset k.endswith('.csv') -> pega somente os arquivos que terminam com .csv
data_set = [k for k in os.listdir(DATASET_DIRECTORY) if k.endswith('.csv')]
data_set_n = sorted(data_set)
   
#pegando os dados de train
training_sets = data_set_n[:int(len(data_set_n)*0.8)]
#pegando os dados de test
test_sets = data_set_n[int(len(data_set_n)*0.8):]


    
#dados de test
for test in test_sets:
    path = DATASET_DIRECTORY+'/'+test
    test = pd.read_csv(path)
    new_y_test = [dict_7classes[k] for k in test['label']]
    y_test = new_y_test
    X_test = test.drop('label', axis=1)
        

for train in training_sets:
    path = DATASET_DIRECTORY+'/'+train
    train = pd.read_csv(path)
    new_y_train = [dict_7classes[k] for k in train['label']]
    y_train = new_y_train
    X_train = train.drop('label', axis=1)

# %%
#transformar dados de treino sampling
X_train_sampling_normalizador = MinMaxScaler()
X_train_normal = X_train_sampling_normalizador.fit_transform(X_train)
    
labelencoder_train  = LabelEncoder()
y_train_sampling = labelencoder_train.fit_transform(y_train)
y_train_normal = np_utils.to_categorical(y_train_sampling)

# %%
#transformar dados de teste
X_teste_sampling_normalizador = MinMaxScaler()
X_test_normal = X_teste_sampling_normalizador.fit_transform(X_test)
    
labelencoder_train  = LabelEncoder()
y_test_sampling = labelencoder_train.fit_transform(y_test)
y_test_normal = np_utils.to_categorical(y_test_sampling)

# %%
#X_train_sampling_nor, y_train_sampling_nor, X_test_normal, y_test_normal 
X_train_3,X_validation_train_dump_3, y_train_dump_3, y_validation_train_dump_3 = model_selection.train_test_split(X_train_normal,y_train_normal,
                                                                            test_size=0.2, random_state=1, stratify=y_train_normal)

# %%
X_train, X_validation, y_train, y_validation = model_selection.train_test_split(X_train_normal,y_train_normal,test_size=0.3, random_state=1, stratify=y_train_normal)

# %%
#essa foi a primeira rede testada com accuracy de 84%
def modeloDense(X_train, metricas):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(500, activation="relu", input_shape=(X_train.shape[-1],)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(8,activation='softmax')
        
    ])
    model.compile(loss='categorical_crossentropy',optimizer=Adam(1e-3), metrics=metricas)
    return model

# %%
def modeloDense(X_train, metricas):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(500, activation="relu", input_shape=(X_train.shape[-1],)),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(8,activation='softmax')
        
    ])
    model.compile(loss='categorical_crossentropy',optimizer=Adam(1e-3), metrics=metricas)
    return model

# %%
def modeloDense2(X_train, metricas):
    model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(500, activation="relu", input_shape=(X_train.shape[-1],)),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(units=500, activation='relu', kernel_initializer="random_uniform", bias_initializer="random_uniform"),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(8,activation='softmax')
        
    ])
    model.compile(loss='categorical_crossentropy',optimizer=Adam(1e-3), metrics=metricas)
    return model

# %%
'''
model_nor2_smote = modeloDense(X_train_3,metricas)
model_normal2_smote = model_nor2_smote.fit(X_train_3, y_train_dump_3, validation_data=(X_validation_train_dump_3, y_validation_train_dump_3),
                  batch_size=300, epochs=200, verbose=1, callbacks=[Mycallback(), checkpoint_callback, callback_stop_patience])
'''
# Out:
# '\nmodel_nor2_smote = modeloDense(X_train_3,metricas)\nmodel_normal2_smote = model_nor2_smote.fit(X_train_3, y_train_dump_3, validation_data=(X_validation_train_dump_3, y_validation_train_dump_3),\n                  batch_size=300, epochs=200, verbose=1, callbacks=[Mycallback(), checkpoint_callback, callback_stop_patience])\n'

# %%
model_nor2_smote = modeloDense(X_train_3,metricas)
model_normal2_smote = model_nor2_smote.fit(X_train_3, y_train_dump_3, validation_data=(X_validation_train_dump_3, y_validation_train_dump_3),
                  batch_size=300, epochs=200, verbose=1, callbacks=[Mycallback(), checkpoint_callback, callback_stop_patience])
# Out:
# Epoch 1/200
# 650/650 [==============================] - ETA: 0s - loss: 0.4240 - fn: 47854.0000 - fp: 40441.0000 - Tn: 1665102.0000 - Tp: 195795.0000 - precision: 0.8288 - recall: 0.8036
# Epoch 1: val_loss improved from inf to 0.35435, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 15s 22ms/step - loss: 0.4240 - fn: 47854.0000 - fp: 40441.0000 - Tn: 1665102.0000 - Tp: 195795.0000 - precision: 0.8288 - recall: 0.8036 - val_loss: 0.3543 - val_fn: 8525.0000 - val_fp: 8071.0000 - val_Tn: 333039.0000 - val_Tp: 40205.0000 - val_precision: 0.8328 - val_recall: 0.8251
# Epoch 2/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3592 - fn: 34308.0000 - fp: 32081.0000 - Tn: 1330819.0000 - Tp: 160392.0000 - precision: 0.8333 - recall: 0.8238
# Epoch 2: val_loss improved from 0.35435 to 0.34736, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 15s 23ms/step - loss: 0.3592 - fn: 34336.0000 - fp: 32109.0000 - Tn: 1332324.0000 - Tp: 160583.0000 - precision: 0.8334 - recall: 0.8238 - val_loss: 0.3474 - val_fn: 8350.0000 - val_fp: 7927.0000 - val_Tn: 333183.0000 - val_Tp: 40380.0000 - val_precision: 0.8359 - val_recall: 0.8286
# Epoch 3/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3525 - fn: 33488.0000 - fp: 31692.0000 - Tn: 1331208.0000 - Tp: 161212.0000 - precision: 0.8357 - recall: 0.8280
# Epoch 3: val_loss improved from 0.34736 to 0.34304, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 16s 24ms/step - loss: 0.3524 - fn: 33525.0000 - fp: 31727.0000 - Tn: 1332706.0000 - Tp: 161394.0000 - precision: 0.8357 - recall: 0.8280 - val_loss: 0.3430 - val_fn: 8113.0000 - val_fp: 7883.0000 - val_Tn: 333227.0000 - val_Tp: 40617.0000 - val_precision: 0.8375 - val_recall: 0.8335
# Epoch 4/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3490 - fn: 33092.0000 - fp: 31401.0000 - Tn: 1333032.0000 - Tp: 161827.0000 - precision: 0.8375 - recall: 0.8302
# Epoch 4: val_loss improved from 0.34304 to 0.33826, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 16s 24ms/step - loss: 0.3490 - fn: 33092.0000 - fp: 31401.0000 - Tn: 1333032.0000 - Tp: 161827.0000 - precision: 0.8375 - recall: 0.8302 - val_loss: 0.3383 - val_fn: 8002.0000 - val_fp: 7733.0000 - val_Tn: 333377.0000 - val_Tp: 40728.0000 - val_precision: 0.8404 - val_recall: 0.8358
# Epoch 5/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3457 - fn: 32771.0000 - fp: 31213.0000 - Tn: 1329587.0000 - Tp: 161629.0000 - precision: 0.8381 - recall: 0.8314
# Epoch 5: val_loss improved from 0.33826 to 0.33713, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3458 - fn: 32852.0000 - fp: 31288.0000 - Tn: 1333145.0000 - Tp: 162067.0000 - precision: 0.8382 - recall: 0.8315 - val_loss: 0.3371 - val_fn: 8227.0000 - val_fp: 7616.0000 - val_Tn: 333494.0000 - val_Tp: 40503.0000 - val_precision: 0.8417 - val_recall: 0.8312
# Epoch 6/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3422 - fn: 32579.0000 - fp: 31036.0000 - Tn: 1333397.0000 - Tp: 162340.0000 - precision: 0.8395 - recall: 0.8329
# Epoch 6: val_loss improved from 0.33713 to 0.33426, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 21ms/step - loss: 0.3422 - fn: 32579.0000 - fp: 31036.0000 - Tn: 1333397.0000 - Tp: 162340.0000 - precision: 0.8395 - recall: 0.8329 - val_loss: 0.3343 - val_fn: 7914.0000 - val_fp: 7634.0000 - val_Tn: 333476.0000 - val_Tp: 40816.0000 - val_precision: 0.8424 - val_recall: 0.8376
# Epoch 7/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3405 - fn: 32353.0000 - fp: 30768.0000 - Tn: 1327932.0000 - Tp: 161747.0000 - precision: 0.8402 - recall: 0.8333
# Epoch 7: val_loss improved from 0.33426 to 0.33037, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3404 - fn: 32491.0000 - fp: 30900.0000 - Tn: 1333533.0000 - Tp: 162428.0000 - precision: 0.8402 - recall: 0.8333 - val_loss: 0.3304 - val_fn: 7990.0000 - val_fp: 7506.0000 - val_Tn: 333604.0000 - val_Tp: 40740.0000 - val_precision: 0.8444 - val_recall: 0.8360
# Epoch 8/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3384 - fn: 32469.0000 - fp: 30914.0000 - Tn: 1333519.0000 - Tp: 162450.0000 - precision: 0.8401 - recall: 0.8334
# Epoch 8: val_loss improved from 0.33037 to 0.32766, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3384 - fn: 32469.0000 - fp: 30914.0000 - Tn: 1333519.0000 - Tp: 162450.0000 - precision: 0.8401 - recall: 0.8334 - val_loss: 0.3277 - val_fn: 7825.0000 - val_fp: 7590.0000 - val_Tn: 333520.0000 - val_Tp: 40905.0000 - val_precision: 0.8435 - val_recall: 0.8394
# Epoch 9/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3368 - fn: 32199.0000 - fp: 30655.0000 - Tn: 1330145.0000 - Tp: 162201.0000 - precision: 0.8410 - recall: 0.8344
# Epoch 9: val_loss did not improve from 0.32766
# 650/650 [==============================] - 16s 25ms/step - loss: 0.3368 - fn: 32290.0000 - fp: 30736.0000 - Tn: 1333697.0000 - Tp: 162629.0000 - precision: 0.8410 - recall: 0.8343 - val_loss: 0.3299 - val_fn: 8025.0000 - val_fp: 7312.0000 - val_Tn: 333798.0000 - val_Tp: 40705.0000 - val_precision: 0.8477 - val_recall: 0.8353
# Epoch 10/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3346 - fn: 32165.0000 - fp: 30651.0000 - Tn: 1332249.0000 - Tp: 162535.0000 - precision: 0.8413 - recall: 0.8348
# Epoch 10: val_loss improved from 0.32766 to 0.32551, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 16s 25ms/step - loss: 0.3346 - fn: 32202.0000 - fp: 30685.0000 - Tn: 1333748.0000 - Tp: 162717.0000 - precision: 0.8413 - recall: 0.8348 - val_loss: 0.3255 - val_fn: 7888.0000 - val_fp: 7461.0000 - val_Tn: 333649.0000 - val_Tp: 40842.0000 - val_precision: 0.8455 - val_recall: 0.8381
# Epoch 11/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3344 - fn: 32080.0000 - fp: 30471.0000 - Tn: 1328229.0000 - Tp: 162020.0000 - precision: 0.8417 - recall: 0.8347
# Epoch 11: val_loss improved from 0.32551 to 0.32342, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 21ms/step - loss: 0.3343 - fn: 32203.0000 - fp: 30588.0000 - Tn: 1333845.0000 - Tp: 162716.0000 - precision: 0.8418 - recall: 0.8348 - val_loss: 0.3234 - val_fn: 7816.0000 - val_fp: 7472.0000 - val_Tn: 333638.0000 - val_Tp: 40914.0000 - val_precision: 0.8456 - val_recall: 0.8396
# Epoch 12/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3327 - fn: 32068.0000 - fp: 30544.0000 - Tn: 1333889.0000 - Tp: 162851.0000 - precision: 0.8421 - recall: 0.8355
# Epoch 12: val_loss did not improve from 0.32342
# 650/650 [==============================] - 13s 19ms/step - loss: 0.3327 - fn: 32068.0000 - fp: 30544.0000 - Tn: 1333889.0000 - Tp: 162851.0000 - precision: 0.8421 - recall: 0.8355 - val_loss: 0.3254 - val_fn: 7831.0000 - val_fp: 7483.0000 - val_Tn: 333627.0000 - val_Tp: 40899.0000 - val_precision: 0.8453 - val_recall: 0.8393
# Epoch 13/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3318 - fn: 31808.0000 - fp: 30354.0000 - Tn: 1328346.0000 - Tp: 162292.0000 - precision: 0.8424 - recall: 0.8361
# Epoch 13: val_loss did not improve from 0.32342
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3318 - fn: 31952.0000 - fp: 30494.0000 - Tn: 1333939.0000 - Tp: 162967.0000 - precision: 0.8424 - recall: 0.8361 - val_loss: 0.3263 - val_fn: 8022.0000 - val_fp: 7621.0000 - val_Tn: 333489.0000 - val_Tp: 40708.0000 - val_precision: 0.8423 - val_recall: 0.8354
# Epoch 14/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3315 - fn: 31819.0000 - fp: 30233.0000 - Tn: 1330567.0000 - Tp: 162581.0000 - precision: 0.8432 - recall: 0.8363
# Epoch 14: val_loss improved from 0.32342 to 0.32321, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 21ms/step - loss: 0.3315 - fn: 31902.0000 - fp: 30310.0000 - Tn: 1334123.0000 - Tp: 163017.0000 - precision: 0.8432 - recall: 0.8363 - val_loss: 0.3232 - val_fn: 7763.0000 - val_fp: 7408.0000 - val_Tn: 333702.0000 - val_Tp: 40967.0000 - val_precision: 0.8469 - val_recall: 0.8407
# Epoch 15/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3306 - fn: 31914.0000 - fp: 30335.0000 - Tn: 1332565.0000 - Tp: 162786.0000 - precision: 0.8429 - recall: 0.8361
# Epoch 15: val_loss did not improve from 0.32321
# 650/650 [==============================] - 13s 19ms/step - loss: 0.3305 - fn: 31946.0000 - fp: 30364.0000 - Tn: 1334069.0000 - Tp: 162973.0000 - precision: 0.8429 - recall: 0.8361 - val_loss: 0.3235 - val_fn: 7860.0000 - val_fp: 7294.0000 - val_Tn: 333816.0000 - val_Tp: 40870.0000 - val_precision: 0.8486 - val_recall: 0.8387
# Epoch 16/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3297 - fn: 31724.0000 - fp: 30150.0000 - Tn: 1330650.0000 - Tp: 162676.0000 - precision: 0.8436 - recall: 0.8368
# Epoch 16: val_loss improved from 0.32321 to 0.32244, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3298 - fn: 31820.0000 - fp: 30243.0000 - Tn: 1334190.0000 - Tp: 163099.0000 - precision: 0.8436 - recall: 0.8368 - val_loss: 0.3224 - val_fn: 7847.0000 - val_fp: 7480.0000 - val_Tn: 333630.0000 - val_Tp: 40883.0000 - val_precision: 0.8453 - val_recall: 0.8390
# Epoch 17/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3295 - fn: 31727.0000 - fp: 30113.0000 - Tn: 1330687.0000 - Tp: 162673.0000 - precision: 0.8438 - recall: 0.8368
# Epoch 17: val_loss improved from 0.32244 to 0.32019, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3294 - fn: 31807.0000 - fp: 30188.0000 - Tn: 1334245.0000 - Tp: 163112.0000 - precision: 0.8438 - recall: 0.8368 - val_loss: 0.3202 - val_fn: 7751.0000 - val_fp: 7350.0000 - val_Tn: 333760.0000 - val_Tp: 40979.0000 - val_precision: 0.8479 - val_recall: 0.8409
# Epoch 18/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3291 - fn: 31625.0000 - fp: 30102.0000 - Tn: 1332798.0000 - Tp: 163075.0000 - precision: 0.8442 - recall: 0.8376
# Epoch 18: val_loss did not improve from 0.32019
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3291 - fn: 31676.0000 - fp: 30150.0000 - Tn: 1334283.0000 - Tp: 163243.0000 - precision: 0.8441 - recall: 0.8375 - val_loss: 0.3207 - val_fn: 7812.0000 - val_fp: 7302.0000 - val_Tn: 333808.0000 - val_Tp: 40918.0000 - val_precision: 0.8486 - val_recall: 0.8397
# Epoch 19/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3283 - fn: 31697.0000 - fp: 30146.0000 - Tn: 1332754.0000 - Tp: 163003.0000 - precision: 0.8439 - recall: 0.8372
# Epoch 19: val_loss did not improve from 0.32019
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3283 - fn: 31726.0000 - fp: 30173.0000 - Tn: 1334260.0000 - Tp: 163193.0000 - precision: 0.8440 - recall: 0.8372 - val_loss: 0.3207 - val_fn: 7853.0000 - val_fp: 7277.0000 - val_Tn: 333833.0000 - val_Tp: 40877.0000 - val_precision: 0.8489 - val_recall: 0.8388
# Epoch 20/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3276 - fn: 31599.0000 - fp: 29979.0000 - Tn: 1330821.0000 - Tp: 162801.0000 - precision: 0.8445 - recall: 0.8375
# Epoch 20: val_loss did not improve from 0.32019
# 650/650 [==============================] - 14s 21ms/step - loss: 0.3276 - fn: 31674.0000 - fp: 30050.0000 - Tn: 1334383.0000 - Tp: 163245.0000 - precision: 0.8445 - recall: 0.8375 - val_loss: 0.3203 - val_fn: 7765.0000 - val_fp: 7427.0000 - val_Tn: 333683.0000 - val_Tp: 40965.0000 - val_precision: 0.8465 - val_recall: 0.8407
# Epoch 21/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3280 - fn: 31771.0000 - fp: 30137.0000 - Tn: 1334296.0000 - Tp: 163148.0000 - precision: 0.8441 - recall: 0.8370
# Epoch 21: val_loss improved from 0.32019 to 0.31894, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3280 - fn: 31771.0000 - fp: 30137.0000 - Tn: 1334296.0000 - Tp: 163148.0000 - precision: 0.8441 - recall: 0.8370 - val_loss: 0.3189 - val_fn: 7663.0000 - val_fp: 7227.0000 - val_Tn: 333883.0000 - val_Tp: 41067.0000 - val_precision: 0.8504 - val_recall: 0.8427
# Epoch 22/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3279 - fn: 31495.0000 - fp: 29926.0000 - Tn: 1328774.0000 - Tp: 162605.0000 - precision: 0.8446 - recall: 0.8377
# Epoch 22: val_loss did not improve from 0.31894
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3279 - fn: 31634.0000 - fp: 30056.0000 - Tn: 1334377.0000 - Tp: 163285.0000 - precision: 0.8445 - recall: 0.8377 - val_loss: 0.3207 - val_fn: 7838.0000 - val_fp: 7336.0000 - val_Tn: 333774.0000 - val_Tp: 40892.0000 - val_precision: 0.8479 - val_recall: 0.8392
# Epoch 23/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3265 - fn: 31490.0000 - fp: 29914.0000 - Tn: 1330886.0000 - Tp: 162910.0000 - precision: 0.8449 - recall: 0.8380
# Epoch 23: val_loss improved from 0.31894 to 0.31768, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3265 - fn: 31589.0000 - fp: 30011.0000 - Tn: 1334422.0000 - Tp: 163330.0000 - precision: 0.8448 - recall: 0.8379 - val_loss: 0.3177 - val_fn: 7582.0000 - val_fp: 7325.0000 - val_Tn: 333785.0000 - val_Tp: 41148.0000 - val_precision: 0.8489 - val_recall: 0.8444
# Epoch 24/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3269 - fn: 31555.0000 - fp: 29994.0000 - Tn: 1332906.0000 - Tp: 163145.0000 - precision: 0.8447 - recall: 0.8379
# Epoch 24: val_loss did not improve from 0.31768
# 650/650 [==============================] - 14s 21ms/step - loss: 0.3269 - fn: 31585.0000 - fp: 30021.0000 - Tn: 1334412.0000 - Tp: 163334.0000 - precision: 0.8447 - recall: 0.8380 - val_loss: 0.3178 - val_fn: 7758.0000 - val_fp: 7316.0000 - val_Tn: 333794.0000 - val_Tp: 40972.0000 - val_precision: 0.8485 - val_recall: 0.8408
# Epoch 25/200
# 646/650 [============================>.] - ETA: 0s - loss: 0.3265 - fn: 31438.0000 - fp: 29735.0000 - Tn: 1326865.0000 - Tp: 162362.0000 - precision: 0.8452 - recall: 0.8378
# Epoch 25: val_loss improved from 0.31768 to 0.31714, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3265 - fn: 31610.0000 - fp: 29888.0000 - Tn: 1334545.0000 - Tp: 163309.0000 - precision: 0.8453 - recall: 0.8378 - val_loss: 0.3171 - val_fn: 7745.0000 - val_fp: 7226.0000 - val_Tn: 333884.0000 - val_Tp: 40985.0000 - val_precision: 0.8501 - val_recall: 0.8411
# Epoch 26/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3255 - fn: 31334.0000 - fp: 29740.0000 - Tn: 1328960.0000 - Tp: 162766.0000 - precision: 0.8455 - recall: 0.8386
# Epoch 26: val_loss did not improve from 0.31714
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3255 - fn: 31477.0000 - fp: 29876.0000 - Tn: 1334557.0000 - Tp: 163442.0000 - precision: 0.8455 - recall: 0.8385 - val_loss: 0.3179 - val_fn: 7709.0000 - val_fp: 7275.0000 - val_Tn: 333835.0000 - val_Tp: 41021.0000 - val_precision: 0.8494 - val_recall: 0.8418
# Epoch 27/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3250 - fn: 31324.0000 - fp: 29684.0000 - Tn: 1333216.0000 - Tp: 163376.0000 - precision: 0.8462 - recall: 0.8391
# Epoch 27: val_loss did not improve from 0.31714
# 650/650 [==============================] - 12s 18ms/step - loss: 0.3250 - fn: 31358.0000 - fp: 29715.0000 - Tn: 1334718.0000 - Tp: 163561.0000 - precision: 0.8463 - recall: 0.8391 - val_loss: 0.3201 - val_fn: 7882.0000 - val_fp: 7312.0000 - val_Tn: 333798.0000 - val_Tp: 40848.0000 - val_precision: 0.8482 - val_recall: 0.8383
# Epoch 28/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3247 - fn: 31341.0000 - fp: 29785.0000 - Tn: 1333115.0000 - Tp: 163359.0000 - precision: 0.8458 - recall: 0.8390
# Epoch 28: val_loss improved from 0.31714 to 0.31386, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3247 - fn: 31375.0000 - fp: 29816.0000 - Tn: 1334617.0000 - Tp: 163544.0000 - precision: 0.8458 - recall: 0.8390 - val_loss: 0.3139 - val_fn: 7638.0000 - val_fp: 7320.0000 - val_Tn: 333790.0000 - val_Tp: 41092.0000 - val_precision: 0.8488 - val_recall: 0.8433
# Epoch 29/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3249 - fn: 31214.0000 - fp: 29549.0000 - Tn: 1329151.0000 - Tp: 162886.0000 - precision: 0.8464 - recall: 0.8392
# Epoch 29: val_loss did not improve from 0.31386
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3247 - fn: 31310.0000 - fp: 29639.0000 - Tn: 1334794.0000 - Tp: 163609.0000 - precision: 0.8466 - recall: 0.8394 - val_loss: 0.3164 - val_fn: 7693.0000 - val_fp: 7293.0000 - val_Tn: 333817.0000 - val_Tp: 41037.0000 - val_precision: 0.8491 - val_recall: 0.8421
# Epoch 30/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3231 - fn: 31050.0000 - fp: 29528.0000 - Tn: 1333372.0000 - Tp: 163650.0000 - precision: 0.8471 - recall: 0.8405
# Epoch 30: val_loss improved from 0.31386 to 0.31375, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3231 - fn: 31087.0000 - fp: 29562.0000 - Tn: 1334871.0000 - Tp: 163832.0000 - precision: 0.8471 - recall: 0.8405 - val_loss: 0.3138 - val_fn: 7660.0000 - val_fp: 7177.0000 - val_Tn: 333933.0000 - val_Tp: 41070.0000 - val_precision: 0.8512 - val_recall: 0.8428
# Epoch 31/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3234 - fn: 31282.0000 - fp: 29677.0000 - Tn: 1334756.0000 - Tp: 163637.0000 - precision: 0.8465 - recall: 0.8395
# Epoch 31: val_loss did not improve from 0.31375
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3234 - fn: 31282.0000 - fp: 29677.0000 - Tn: 1334756.0000 - Tp: 163637.0000 - precision: 0.8465 - recall: 0.8395 - val_loss: 0.3151 - val_fn: 7633.0000 - val_fp: 7141.0000 - val_Tn: 333969.0000 - val_Tp: 41097.0000 - val_precision: 0.8520 - val_recall: 0.8434
# Epoch 32/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3220 - fn: 31126.0000 - fp: 29546.0000 - Tn: 1333354.0000 - Tp: 163574.0000 - precision: 0.8470 - recall: 0.8401
# Epoch 32: val_loss improved from 0.31375 to 0.31280, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 14s 21ms/step - loss: 0.3220 - fn: 31158.0000 - fp: 29577.0000 - Tn: 1334856.0000 - Tp: 163761.0000 - precision: 0.8470 - recall: 0.8401 - val_loss: 0.3128 - val_fn: 7558.0000 - val_fp: 7247.0000 - val_Tn: 333863.0000 - val_Tp: 41172.0000 - val_precision: 0.8503 - val_recall: 0.8449
# Epoch 33/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3215 - fn: 31163.0000 - fp: 29519.0000 - Tn: 1334914.0000 - Tp: 163756.0000 - precision: 0.8473 - recall: 0.8401
# Epoch 33: val_loss did not improve from 0.31280
# 650/650 [==============================] - 12s 18ms/step - loss: 0.3215 - fn: 31163.0000 - fp: 29519.0000 - Tn: 1334914.0000 - Tp: 163756.0000 - precision: 0.8473 - recall: 0.8401 - val_loss: 0.3145 - val_fn: 7540.0000 - val_fp: 7196.0000 - val_Tn: 333914.0000 - val_Tp: 41190.0000 - val_precision: 0.8513 - val_recall: 0.8453
# Epoch 34/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3211 - fn: 31160.0000 - fp: 29486.0000 - Tn: 1334947.0000 - Tp: 163759.0000 - precision: 0.8474 - recall: 0.8401
# Epoch 34: val_loss improved from 0.31280 to 0.31174, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3211 - fn: 31160.0000 - fp: 29486.0000 - Tn: 1334947.0000 - Tp: 163759.0000 - precision: 0.8474 - recall: 0.8401 - val_loss: 0.3117 - val_fn: 7664.0000 - val_fp: 7206.0000 - val_Tn: 333904.0000 - val_Tp: 41066.0000 - val_precision: 0.8507 - val_recall: 0.8427
# Epoch 35/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3222 - fn: 31126.0000 - fp: 29491.0000 - Tn: 1329209.0000 - Tp: 162974.0000 - precision: 0.8468 - recall: 0.8396
# Epoch 35: val_loss did not improve from 0.31174
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3221 - fn: 31250.0000 - fp: 29609.0000 - Tn: 1334824.0000 - Tp: 163669.0000 - precision: 0.8468 - recall: 0.8397 - val_loss: 0.3136 - val_fn: 7663.0000 - val_fp: 7209.0000 - val_Tn: 333901.0000 - val_Tp: 41067.0000 - val_precision: 0.8507 - val_recall: 0.8427
# Epoch 36/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3205 - fn: 31008.0000 - fp: 29426.0000 - Tn: 1335007.0000 - Tp: 163911.0000 - precision: 0.8478 - recall: 0.8409
# Epoch 36: val_loss improved from 0.31174 to 0.31101, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3205 - fn: 31008.0000 - fp: 29426.0000 - Tn: 1335007.0000 - Tp: 163911.0000 - precision: 0.8478 - recall: 0.8409 - val_loss: 0.3110 - val_fn: 7510.0000 - val_fp: 7140.0000 - val_Tn: 333970.0000 - val_Tp: 41220.0000 - val_precision: 0.8524 - val_recall: 0.8459
# Epoch 37/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3226 - fn: 31243.0000 - fp: 29616.0000 - Tn: 1329084.0000 - Tp: 162857.0000 - precision: 0.8461 - recall: 0.8390
# Epoch 37: val_loss improved from 0.31101 to 0.31086, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3226 - fn: 31373.0000 - fp: 29742.0000 - Tn: 1334691.0000 - Tp: 163546.0000 - precision: 0.8461 - recall: 0.8390 - val_loss: 0.3109 - val_fn: 7598.0000 - val_fp: 7119.0000 - val_Tn: 333991.0000 - val_Tp: 41132.0000 - val_precision: 0.8525 - val_recall: 0.8441
# Epoch 38/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3205 - fn: 31104.0000 - fp: 29575.0000 - Tn: 1331225.0000 - Tp: 163296.0000 - precision: 0.8467 - recall: 0.8400
# Epoch 38: val_loss did not improve from 0.31086
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3205 - fn: 31193.0000 - fp: 29661.0000 - Tn: 1334772.0000 - Tp: 163726.0000 - precision: 0.8466 - recall: 0.8400 - val_loss: 0.3150 - val_fn: 7665.0000 - val_fp: 7194.0000 - val_Tn: 333916.0000 - val_Tp: 41065.0000 - val_precision: 0.8509 - val_recall: 0.8427
# Epoch 39/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3209 - fn: 30958.0000 - fp: 29425.0000 - Tn: 1331375.0000 - Tp: 163442.0000 - precision: 0.8474 - recall: 0.8408
# Epoch 39: val_loss did not improve from 0.31086
# 650/650 [==============================] - 14s 21ms/step - loss: 0.3208 - fn: 31029.0000 - fp: 29492.0000 - Tn: 1334941.0000 - Tp: 163890.0000 - precision: 0.8475 - recall: 0.8408 - val_loss: 0.3124 - val_fn: 7738.0000 - val_fp: 7276.0000 - val_Tn: 333834.0000 - val_Tp: 40992.0000 - val_precision: 0.8493 - val_recall: 0.8412
# Epoch 40/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3209 - fn: 31060.0000 - fp: 29376.0000 - Tn: 1331424.0000 - Tp: 163340.0000 - precision: 0.8476 - recall: 0.8402
# Epoch 40: val_loss improved from 0.31086 to 0.30853, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 21ms/step - loss: 0.3209 - fn: 31145.0000 - fp: 29458.0000 - Tn: 1334975.0000 - Tp: 163774.0000 - precision: 0.8476 - recall: 0.8402 - val_loss: 0.3085 - val_fn: 7506.0000 - val_fp: 7237.0000 - val_Tn: 333873.0000 - val_Tp: 41224.0000 - val_precision: 0.8507 - val_recall: 0.8460
# Epoch 41/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3203 - fn: 31242.0000 - fp: 29743.0000 - Tn: 1334690.0000 - Tp: 163677.0000 - precision: 0.8462 - recall: 0.8397
# Epoch 41: val_loss did not improve from 0.30853
# 650/650 [==============================] - 12s 19ms/step - loss: 0.3203 - fn: 31242.0000 - fp: 29743.0000 - Tn: 1334690.0000 - Tp: 163677.0000 - precision: 0.8462 - recall: 0.8397 - val_loss: 0.3110 - val_fn: 7630.0000 - val_fp: 7114.0000 - val_Tn: 333996.0000 - val_Tp: 41100.0000 - val_precision: 0.8524 - val_recall: 0.8434
# Epoch 42/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3192 - fn: 30688.0000 - fp: 29187.0000 - Tn: 1329513.0000 - Tp: 163412.0000 - precision: 0.8485 - recall: 0.8419
# Epoch 42: val_loss did not improve from 0.30853
# 650/650 [==============================] - 12s 18ms/step - loss: 0.3192 - fn: 30831.0000 - fp: 29321.0000 - Tn: 1335112.0000 - Tp: 164088.0000 - precision: 0.8484 - recall: 0.8418 - val_loss: 0.3126 - val_fn: 7687.0000 - val_fp: 7274.0000 - val_Tn: 333836.0000 - val_Tp: 41043.0000 - val_precision: 0.8495 - val_recall: 0.8423
# Epoch 43/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3199 - fn: 30851.0000 - fp: 29256.0000 - Tn: 1329444.0000 - Tp: 163249.0000 - precision: 0.8480 - recall: 0.8411
# Epoch 43: val_loss did not improve from 0.30853
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3199 - fn: 30976.0000 - fp: 29379.0000 - Tn: 1335054.0000 - Tp: 163943.0000 - precision: 0.8480 - recall: 0.8411 - val_loss: 0.3089 - val_fn: 7590.0000 - val_fp: 7118.0000 - val_Tn: 333992.0000 - val_Tp: 41140.0000 - val_precision: 0.8525 - val_recall: 0.8442
# Epoch 44/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3187 - fn: 30776.0000 - fp: 29277.0000 - Tn: 1331523.0000 - Tp: 163624.0000 - precision: 0.8482 - recall: 0.8417
# Epoch 44: val_loss did not improve from 0.30853
# 650/650 [==============================] - 13s 21ms/step - loss: 0.3186 - fn: 30841.0000 - fp: 29335.0000 - Tn: 1335098.0000 - Tp: 164078.0000 - precision: 0.8483 - recall: 0.8418 - val_loss: 0.3106 - val_fn: 7626.0000 - val_fp: 7043.0000 - val_Tn: 334067.0000 - val_Tp: 41104.0000 - val_precision: 0.8537 - val_recall: 0.8435
# Epoch 45/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3196 - fn: 31026.0000 - fp: 29440.0000 - Tn: 1333460.0000 - Tp: 163674.0000 - precision: 0.8476 - recall: 0.8406
# Epoch 45: val_loss did not improve from 0.30853
# 650/650 [==============================] - 15s 23ms/step - loss: 0.3197 - fn: 31069.0000 - fp: 29483.0000 - Tn: 1334950.0000 - Tp: 163850.0000 - precision: 0.8475 - recall: 0.8406 - val_loss: 0.3091 - val_fn: 7605.0000 - val_fp: 7160.0000 - val_Tn: 333950.0000 - val_Tp: 41125.0000 - val_precision: 0.8517 - val_recall: 0.8439
# Epoch 46/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3192 - fn: 30978.0000 - fp: 29335.0000 - Tn: 1333565.0000 - Tp: 163722.0000 - precision: 0.8481 - recall: 0.8409
# Epoch 46: val_loss did not improve from 0.30853
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3192 - fn: 31013.0000 - fp: 29370.0000 - Tn: 1335063.0000 - Tp: 163906.0000 - precision: 0.8480 - recall: 0.8409 - val_loss: 0.3115 - val_fn: 7724.0000 - val_fp: 7167.0000 - val_Tn: 333943.0000 - val_Tp: 41006.0000 - val_precision: 0.8512 - val_recall: 0.8415
# Epoch 47/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3172 - fn: 30809.0000 - fp: 29246.0000 - Tn: 1331554.0000 - Tp: 163591.0000 - precision: 0.8483 - recall: 0.8415
# Epoch 47: val_loss did not improve from 0.30853
# 650/650 [==============================] - 14s 21ms/step - loss: 0.3171 - fn: 30877.0000 - fp: 29312.0000 - Tn: 1335121.0000 - Tp: 164042.0000 - precision: 0.8484 - recall: 0.8416 - val_loss: 0.3095 - val_fn: 7665.0000 - val_fp: 7173.0000 - val_Tn: 333937.0000 - val_Tp: 41065.0000 - val_precision: 0.8513 - val_recall: 0.8427
# Epoch 48/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3175 - fn: 30669.0000 - fp: 29148.0000 - Tn: 1331652.0000 - Tp: 163731.0000 - precision: 0.8489 - recall: 0.8422
# Epoch 48: val_loss improved from 0.30853 to 0.30585, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 21ms/step - loss: 0.3175 - fn: 30748.0000 - fp: 29221.0000 - Tn: 1335212.0000 - Tp: 164171.0000 - precision: 0.8489 - recall: 0.8423 - val_loss: 0.3058 - val_fn: 7503.0000 - val_fp: 7083.0000 - val_Tn: 334027.0000 - val_Tp: 41227.0000 - val_precision: 0.8534 - val_recall: 0.8460
# Epoch 49/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3152 - fn: 30651.0000 - fp: 28974.0000 - Tn: 1335459.0000 - Tp: 164268.0000 - precision: 0.8501 - recall: 0.8428
# Epoch 49: val_loss did not improve from 0.30585
# 650/650 [==============================] - 14s 21ms/step - loss: 0.3152 - fn: 30651.0000 - fp: 28974.0000 - Tn: 1335459.0000 - Tp: 164268.0000 - precision: 0.8501 - recall: 0.8428 - val_loss: 0.3061 - val_fn: 7421.0000 - val_fp: 7214.0000 - val_Tn: 333896.0000 - val_Tp: 41309.0000 - val_precision: 0.8513 - val_recall: 0.8477
# Epoch 50/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3162 - fn: 30423.0000 - fp: 28898.0000 - Tn: 1335535.0000 - Tp: 164496.0000 - precision: 0.8506 - recall: 0.8439
# Epoch 50: val_loss improved from 0.30585 to 0.30124, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 15s 23ms/step - loss: 0.3162 - fn: 30423.0000 - fp: 28898.0000 - Tn: 1335535.0000 - Tp: 164496.0000 - precision: 0.8506 - recall: 0.8439 - val_loss: 0.3012 - val_fn: 7254.0000 - val_fp: 6876.0000 - val_Tn: 334234.0000 - val_Tp: 41476.0000 - val_precision: 0.8578 - val_recall: 0.8511
# Epoch 51/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3143 - fn: 30352.0000 - fp: 28802.0000 - Tn: 1334098.0000 - Tp: 164348.0000 - precision: 0.8509 - recall: 0.8441
# Epoch 51: val_loss did not improve from 0.30124
# 650/650 [==============================] - 14s 22ms/step - loss: 0.3142 - fn: 30375.0000 - fp: 28823.0000 - Tn: 1335610.0000 - Tp: 164544.0000 - precision: 0.8509 - recall: 0.8442 - val_loss: 0.3028 - val_fn: 7568.0000 - val_fp: 7057.0000 - val_Tn: 334053.0000 - val_Tp: 41162.0000 - val_precision: 0.8536 - val_recall: 0.8447
# Epoch 52/200
# 647/650 [============================>.] - ETA: 0s - loss: 0.3128 - fn: 30136.0000 - fp: 28552.0000 - Tn: 1330148.0000 - Tp: 163964.0000 - precision: 0.8517 - recall: 0.8447
# Epoch 52: val_loss did not improve from 0.30124
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3126 - fn: 30238.0000 - fp: 28645.0000 - Tn: 1335788.0000 - Tp: 164681.0000 - precision: 0.8518 - recall: 0.8449 - val_loss: 0.3045 - val_fn: 7429.0000 - val_fp: 6895.0000 - val_Tn: 334215.0000 - val_Tp: 41301.0000 - val_precision: 0.8569 - val_recall: 0.8475
# Epoch 53/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3128 - fn: 30077.0000 - fp: 28523.0000 - Tn: 1335910.0000 - Tp: 164842.0000 - precision: 0.8525 - recall: 0.8457
# Epoch 53: val_loss improved from 0.30124 to 0.29929, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 13s 20ms/step - loss: 0.3128 - fn: 30077.0000 - fp: 28523.0000 - Tn: 1335910.0000 - Tp: 164842.0000 - precision: 0.8525 - recall: 0.8457 - val_loss: 0.2993 - val_fn: 7213.0000 - val_fp: 6764.0000 - val_Tn: 334346.0000 - val_Tp: 41517.0000 - val_precision: 0.8599 - val_recall: 0.8520
# Epoch 54/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3128 - fn: 30062.0000 - fp: 28483.0000 - Tn: 1334417.0000 - Tp: 164638.0000 - precision: 0.8525 - recall: 0.8456
# Epoch 54: val_loss improved from 0.29929 to 0.29909, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 16s 24ms/step - loss: 0.3127 - fn: 30086.0000 - fp: 28506.0000 - Tn: 1335927.0000 - Tp: 164833.0000 - precision: 0.8526 - recall: 0.8456 - val_loss: 0.2991 - val_fn: 7342.0000 - val_fp: 6762.0000 - val_Tn: 334348.0000 - val_Tp: 41388.0000 - val_precision: 0.8596 - val_recall: 0.8493
# Epoch 55/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3116 - fn: 30048.0000 - fp: 28503.0000 - Tn: 1335930.0000 - Tp: 164871.0000 - precision: 0.8526 - recall: 0.8458
# Epoch 55: val_loss improved from 0.29909 to 0.29909, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 15s 23ms/step - loss: 0.3116 - fn: 30048.0000 - fp: 28503.0000 - Tn: 1335930.0000 - Tp: 164871.0000 - precision: 0.8526 - recall: 0.8458 - val_loss: 0.2991 - val_fn: 7337.0000 - val_fp: 6917.0000 - val_Tn: 334193.0000 - val_Tp: 41393.0000 - val_precision: 0.8568 - val_recall: 0.8494
# Epoch 56/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3118 - fn: 30030.0000 - fp: 28495.0000 - Tn: 1335938.0000 - Tp: 164889.0000 - precision: 0.8527 - recall: 0.8459
# Epoch 56: val_loss improved from 0.29909 to 0.29715, saving model to melhor__reduzido_2.h5
# 650/650 [==============================] - 16s 25ms/step - loss: 0.3118 - fn: 30030.0000 - fp: 28495.0000 - Tn: 1335938.0000 - Tp: 164889.0000 - precision: 0.8527 - recall: 0.8459 - val_loss: 0.2971 - val_fn: 7253.0000 - val_fp: 6768.0000 - val_Tn: 334342.0000 - val_Tp: 41477.0000 - val_precision: 0.8597 - val_recall: 0.8512
# Epoch 57/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3114 - fn: 30030.0000 - fp: 28570.0000 - Tn: 1335863.0000 - Tp: 164889.0000 - precision: 0.8523 - recall: 0.8459
# Epoch 57: val_loss did not improve from 0.29715
# 650/650 [==============================] - 16s 25ms/step - loss: 0.3114 - fn: 30030.0000 - fp: 28570.0000 - Tn: 1335863.0000 - Tp: 164889.0000 - precision: 0.8523 - recall: 0.8459 - val_loss: 0.3009 - val_fn: 7245.0000 - val_fp: 6867.0000 - val_Tn: 334243.0000 - val_Tp: 41485.0000 - val_precision: 0.8580 - val_recall: 0.8513
# Epoch 58/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3112 - fn: 30049.0000 - fp: 28590.0000 - Tn: 1334310.0000 - Tp: 164651.0000 - precision: 0.8521 - recall: 0.8457
# Epoch 58: val_loss did not improve from 0.29715
# 650/650 [==============================] - 16s 25ms/step - loss: 0.3112 - fn: 30081.0000 - fp: 28622.0000 - Tn: 1335811.0000 - Tp: 164838.0000 - precision: 0.8521 - recall: 0.8457 - val_loss: 0.2992 - val_fn: 7354.0000 - val_fp: 6913.0000 - val_Tn: 334197.0000 - val_Tp: 41376.0000 - val_precision: 0.8568 - val_recall: 0.8491
# Epoch 59/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3110 - fn: 29951.0000 - fp: 28451.0000 - Tn: 1334449.0000 - Tp: 164749.0000 - precision: 0.8527 - recall: 0.8462
# Epoch 59: val_loss did not improve from 0.29715
# 650/650 [==============================] - 16s 24ms/step - loss: 0.3110 - fn: 29992.0000 - fp: 28487.0000 - Tn: 1335946.0000 - Tp: 164927.0000 - precision: 0.8527 - recall: 0.8461 - val_loss: 0.2984 - val_fn: 7203.0000 - val_fp: 6874.0000 - val_Tn: 334236.0000 - val_Tp: 41527.0000 - val_precision: 0.8580 - val_recall: 0.8522
# Epoch 60/200
# 650/650 [==============================] - ETA: 0s - loss: 0.3099 - fn: 29852.0000 - fp: 28284.0000 - Tn: 1336149.0000 - Tp: 165067.0000 - precision: 0.8537 - recall: 0.8468
# Epoch 60: val_loss did not improve from 0.29715
# 650/650 [==============================] - 16s 25ms/step - loss: 0.3099 - fn: 29852.0000 - fp: 28284.0000 - Tn: 1336149.0000 - Tp: 165067.0000 - precision: 0.8537 - recall: 0.8468 - val_loss: 0.2979 - val_fn: 7281.0000 - val_fp: 6831.0000 - val_Tn: 334279.0000 - val_Tp: 41449.0000 - val_precision: 0.8585 - val_recall: 0.8506
# Epoch 61/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3110 - fn: 29973.0000 - fp: 28359.0000 - Tn: 1332441.0000 - Tp: 164427.0000 - precision: 0.8529 - recall: 0.8458
# Epoch 61: val_loss did not improve from 0.29715
# 650/650 [==============================] - 17s 26ms/step - loss: 0.3110 - fn: 30055.0000 - fp: 28439.0000 - Tn: 1335994.0000 - Tp: 164864.0000 - precision: 0.8529 - recall: 0.8458 - val_loss: 0.3007 - val_fn: 7278.0000 - val_fp: 6853.0000 - val_Tn: 334257.0000 - val_Tp: 41452.0000 - val_precision: 0.8581 - val_recall: 0.8506
# Epoch 62/200
# 649/650 [============================>.] - ETA: 0s - loss: 0.3101 - fn: 30010.0000 - fp: 28527.0000 - Tn: 1334373.0000 - Tp: 164690.0000 - precision: 0.8524 - recall: 0.8459
# Epoch 62: val_loss did not improve from 0.29715
# 650/650 [==============================] - 16s 24ms/step - loss: 0.3101 - fn: 30032.0000 - fp: 28548.0000 - Tn: 1335885.0000 - Tp: 164887.0000 - precision: 0.8524 - recall: 0.8459 - val_loss: 0.3006 - val_fn: 7324.0000 - val_fp: 6798.0000 - val_Tn: 334312.0000 - val_Tp: 41406.0000 - val_precision: 0.8590 - val_recall: 0.8497
# Epoch 63/200
# 648/650 [============================>.] - ETA: 0s - loss: 0.3096 - fn: 29830.0000 - fp: 28298.0000 - Tn: 1332502.0000 - Tp: 164570.0000 - precision: 0.8533 - recall: 0.8466
# Epoch 63: val_loss did not improve from 0.29715
# 650/650 [==============================] - 15s 24ms/step - loss: 0.3096 - fn: 29901.0000 - fp: 28364.0000 - Tn: 1336069.0000 - Tp: 165018.0000 - precision: 0.8533 - recall: 0.8466 - val_loss: 0.2984 - val_fn: 7266.0000 - val_fp: 6799.0000 - val_Tn: 334311.0000 - val_Tp: 41464.0000 - val_precision: 0.8591 - val_recall: 0.8509
# Epoch 64/200
# 248/650 [==========>...................] - ETA: 9s - loss: 0.3094 - fn: 11356.0000 - fp: 10794.0000 - Tn: 510006.0000 - Tp: 63044.0000 - precision: 0.8538 - recall: 0.8474

# %%
#X_train, X_validation, y_train, y_validation
model_Dens2 = modeloDense2(X_train,metricas)
model_Dense2_mais = model_Dens2.fit(X_train, y_train, validation_data=(X_validation, y_validation),
                  batch_size=300, epochs=200, verbose=1, callbacks=[Mycallback(), checkpoint_callback, callback_stop_patience])

# %%
plt.plot(model_normal2_smote.history["loss"], label="loss_train")
plt.plot(model_normal2_smote.history["val_loss"], label="loss_teste")
plt.plot(model_normal2_smote.history["precision"], label="precisão")
plt.plot(model_normal2_smote.history["val_precision"], label="val_precisão")
#plt.plot(history.history["tp"], label="tp")
#plt.plot(history.history["val_tp"], label="val_tp")
plt.legend()

# %%
TrainPredictions = model_nor2_smote.predict(X_test_normal)
#convertendo dados onehot encoder para rotulos de classes
TrainPredictions_convert = np.argmax(TrainPredictions, axis=1)
y_train_rotulos = np.argmax(y_test_normal, axis=1)
# Out:
# 7336/7336 [==============================] - 13s 2ms/step

# %%
conf = confusion_matrix(y_train_rotulos, TrainPredictions_convert)

classes = ['DDoS', 'DoS','Mirai','Benign','Spoofing','Recon','Web','BruteForce']
#classes = [0,1,2,3,4,5,6,7]
#plot confusion matrix
plt.imshow(conf, interpolation='nearest', cmap=plt.cm.Greens)
plt.title("Train Confusion Matrix")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

fmt = 'd'
thresh = conf.max() / 2.
for i, j in itertools.product(range(conf.shape[0]), range(conf.shape[1])):
    plt.text(j, i, format(conf[i, j], fmt),
             horizontalalignment="center",
             color="white" if conf[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 23.52222222222222, 'Predicted label')

# %%
print('Confusion Matrix\n')
print(conf)
#Micro: Foca no total agregado de verdadeiros positivos, falsos negativos e falsos positivos. Cada instância conta igualmente.
#importar as métricas 
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print(f'Accuracy: {accuracy_score(y_train_rotulos,TrainPredictions_convert)}\n')
print(f"Micro Precision: {precision_score(y_train_rotulos,TrainPredictions_convert, average='micro')}\n")
print(f"Micro Recall: {recall_score(y_train_rotulos,TrainPredictions_convert, average='micro')}\n")
print(f'Micro F1_score: {f1_score(y_train_rotulos,TrainPredictions_convert, average="micro")}\n')

#Macro: Calcula a métrica para cada classe individualmente e tira a média aritmética. Cada classe conta igualmente.
print(f'Macro Precision: {precision_score(y_train_rotulos,TrainPredictions_convert, average="macro")}\n')
print(f'Macro Recall: {recall_score(y_train_rotulos,TrainPredictions_convert, average="macro")}\n')
print(f'Macro F1_score: {f1_score(y_train_rotulos,TrainPredictions_convert, average="macro")}\n')

#Weighted: Calcula a métrica para cada classe individualmente e tira a média ponderada pelo número de instâncias em cada classe. Considera o desequilíbrio de classes.
print(f'Weighted Precision: {precision_score(y_train_rotulos,TrainPredictions_convert, average="weighted")}\n')
print(f'Weighted Recall: {recall_score(y_train_rotulos,TrainPredictions_convert, average="weighted")}\n')
print(f'Weighted F1_score: {f1_score(y_train_rotulos,TrainPredictions_convert, average="weighted")}\n')

#me tráz métricas de avaliação para modelos multiclasses
from sklearn.metrics import classification_report
print('\nClassification Report\n')
print(classification_report(y_train_rotulos, TrainPredictions_convert,target_names= ['DDoS', 'DoS','Mirai','Benign','Spoofing','Recon','Web','BruteForce']))
#target_names= ['DDoS', 'DoS','Mirai','Benign','Spoofing','Recon','Web','BruteForce']
#target_names= ['0', '1','2','3','4','5','6','7']
# Out:
# Confusion Matrix
#
# [[  5291      0      1      0      0     24    165      0]
#  [    59     11      0      0      0      4      5      0]
#  [     0      0 169149   1353      6     27      5      0]
#  [     0      0  32324   8486      9     34      0      1]
#  [     1      0     69      9  13383     10      1      0]
#  [   753      0     75      3      0    798    115      0]
#  [   933      0      2      1      0     55   1444      0]
#  [    96      0      0      0      0     11     28      4]]
# Accuracy: 0.8458795714498711
#
# Micro Precision: 0.8458795714498711
#
# Micro Recall: 0.8458795714498711
#
# Micro F1_score: 0.8458795714498711
#
# Macro Precision: 0.8610825477051496
#
# Macro Recall: 0.5471022966676561
#
# Macro F1_score: 0.5820321110722345
#
# Weighted Precision: 0.8495059403452406
#
# Weighted Recall: 0.8458795714498711
#
# Weighted F1_score: 0.807029665126177
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#         DDoS       0.74      0.97      0.84      5481
#          DoS       1.00      0.14      0.24        79
#        Mirai       0.84      0.99      0.91    170540
#       Benign       0.86      0.21      0.33     40854
#     Spoofing       1.00      0.99      1.00     13473
#        Recon       0.83      0.46      0.59      1744
#          Web       0.82      0.59      0.69      2435
#   BruteForce       0.80      0.03      0.06       139
#
#     accuracy                           0.85    234745
#    macro avg       0.86      0.55      0.58    234745
# weighted avg       0.85      0.85      0.81    234745
